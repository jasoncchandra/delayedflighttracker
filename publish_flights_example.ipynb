# %%
import json
import asyncio

from aiohttp import ClientSession, BasicAuth
from python_opensky import OpenSky, BoundingBox
from pyensign.ensign import authenticate, publisher

# %% [markdown]
# # Configuration

# %%
OPENSKY_CREDS_PATH="opensky-creds.json"
ENSIGN_CREDS_PATH="ensign-creds.json"

def load_opensky_creds():
    with open(OPENSKY_CREDS_PATH) as f:
        creds = json.load(f)
        return BasicAuth(login=creds["username"], password=creds["password"])

OPENSKY_CREDS = load_opensky_creds()

# %%
BOUNDING_BOX = BoundingBox(
    min_latitude=19,
    max_latitude=65,
    min_longitude=-162,
    max_longitude=-67,
)

INTERVAL_SEC=5

# %% [markdown]
# # Publish Flight Updates

# %%
@publisher("flight-positions")
async def get_flights():
    async with ClientSession() as session:
        async with OpenSky(session=session) as opensky:
            await opensky.authenticate(OPENSKY_CREDS)
            
            response = await opensky.get_states(bounding_box=BOUNDING_BOX)
            for vector in response.states:
                yield {
                    "icao24": vector.icao24,
                    "callsign": vector.callsign,
                    "origin_country": vector.origin_country,
                    "time_position": vector.time_position,
                    "last_contact": vector.last_contact,
                    "longitude": vector.longitude,
                    "latitude": vector.latitude,
                    "geo_altitude": vector.geo_altitude,
                    "on_ground": vector.on_ground,
                    "velocity": vector.velocity,
                    "true_track": vector.true_track,
                    "vertical_rate": vector.vertical_rate,
                    "sensors": vector.sensors,
                    "barometric_altitude": vector.barometric_altitude,
                    "transponder_code": vector.transponder_code,
                    "special_purpose_indicator": vector.special_purpose_indicator,
                    "position_source": vector.position_source,
                    "category": vector.category,
                }
                
@authenticate(cred_path=ENSIGN_CREDS_PATH)
async def poll_flights():
    for i in range(10):
        async for data in get_flights():
            print(data)
        await asyncio.sleep(INTERVAL_SEC)
            
    # Wait for pending events to get published
    await asyncio.sleep(1)

# %%
await poll_flights()
# Out:
# {'icao24': 'a40bd8', 'callsign': 'N36VK   ', 'origin_country': 'United States', 'time_position': 1697328160, 'last_contact': 1697328161, 'longitude': -96.6299, 'latitude': 31.8436, 'geo_altitude': 1988.82, 'on_ground': False, 'velocity': 63.63, 'true_track': 337.17, 'vertical_rate': 0.33, 'sensors': None, 'barometric_altitude': 1935.48, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LIGHT: 2>}
# {'icao24': 'ab1644', 'callsign': 'UAL2410 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -90.3431, 'latitude': 33.9986, 'geo_altitude': 11818.62, 'on_ground': False, 'velocity': 277.4, 'true_track': 53.6, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 11277.6, 'transponder_code': '2441', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LARGE: 4>}
# {'icao24': 'aa3cbe', 'callsign': 'N759PA  ', 'origin_country': 'United States', 'time_position': 1697328008, 'last_contact': 1697328009, 'longitude': -112.0554, 'latitude': 41.7922, 'geo_altitude': 2476.5, 'on_ground': False, 'velocity': 62.97, 'true_track': 85.31, 'vertical_rate': 0.65, 'sensors': None, 'barometric_altitude': 2354.58, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a57b26', 'callsign': 'N452SM  ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -104.4885, 'latitude': 38.4564, 'geo_altitude': 2057.4, 'on_ground': False, 'velocity': 45.79, 'true_track': 205.99, 'vertical_rate': -3.25, 'sensors': None, 'barometric_altitude': 1943.1, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'ade18c', 'callsign': 'AAL1322 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -104.0153, 'latitude': 39.4546, 'geo_altitude': 5661.66, 'on_ground': False, 'velocity': 171.31, 'true_track': 306.7, 'vertical_rate': -5.85, 'sensors': None, 'barometric_altitude': 5455.92, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'a808ba', 'callsign': 'N61696  ', 'origin_country': 'United States', 'time_position': 1697328030, 'last_contact': 1697328030, 'longitude': -122.5873, 'latitude': 38.2472, 'geo_altitude': 160.02, 'on_ground': False, 'velocity': 31.28, 'true_track': 306.3, 'vertical_rate': -2.6, 'sensors': None, 'barometric_altitude': 152.4, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LIGHT: 2>}
# {'icao24': 'abd9d9', 'callsign': 'SWA2023 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -121.2292, 'latitude': 38.9339, 'geo_altitude': 1866.9, 'on_ground': False, 'velocity': 133.08, 'true_track': 251.99, 'vertical_rate': -7.48, 'sensors': None, 'barometric_altitude': 1798.32, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'c047d3', 'callsign': 'CGBFE   ', 'origin_country': 'Canada', 'time_position': 1697328161, 'last_contact': 1697328161, 'longitude': -113.5448, 'latitude': 53.6887, 'geo_altitude': 4693.92, 'on_ground': False, 'velocity': 87.06, 'true_track': 356.95, 'vertical_rate': 4.55, 'sensors': None, 'barometric_altitude': 4655.82, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LIGHT: 2>}
# {'icao24': '440da1', 'callsign': 'SKV222  ', 'origin_country': 'Austria', 'time_position': 1697328162, 'last_contact': 1697328163, 'longitude': -73.3682, 'latitude': 43.3056, 'geo_altitude': 7818.12, 'on_ground': False, 'velocity': 210.63, 'true_track': 209.88, 'vertical_rate': -4.88, 'sensors': None, 'barometric_altitude': 7863.84, 'transponder_code': '0745', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'c07d20', 'callsign': 'JZA7976 ', 'origin_country': 'Canada', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -74.881, 'latitude': 45.0597, 'geo_altitude': 4389.12, 'on_ground': False, 'velocity': 181.17, 'true_track': 66.93, 'vertical_rate': -7.15, 'sensors': None, 'barometric_altitude': 4472.94, 'transponder_code': '2264', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.SMALL: 3>}
# {'icao24': 'aa8c34', 'callsign': 'N779TW  ', 'origin_country': 'United States', 'time_position': 1697328161, 'last_contact': 1697328162, 'longitude': -85.4422, 'latitude': 39.6824, 'geo_altitude': 1158.24, 'on_ground': False, 'velocity': 89.61, 'true_track': 285.31, 'vertical_rate': -0.33, 'sensors': None, 'barometric_altitude': 1226.82, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a678e5', 'callsign': 'JTZ516  ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -96.2112, 'latitude': 30.1398, 'geo_altitude': 2186.94, 'on_ground': False, 'velocity': 152.87, 'true_track': 133.09, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 2087.88, 'transponder_code': '2325', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a305fd', 'callsign': 'SKW4082 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328163, 'longitude': -111.5058, 'latitude': 40.7566, 'geo_altitude': 6050.28, 'on_ground': False, 'velocity': 208.87, 'true_track': 130.0, 'vertical_rate': 6.5, 'sensors': None, 'barometric_altitude': 5806.44, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'aa56d8', 'callsign': 'UAL1906 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328163, 'longitude': -86.5022, 'latitude': 42.6026, 'geo_altitude': 6111.24, 'on_ground': False, 'velocity': 202.26, 'true_track': 255.72, 'vertical_rate': 0.33, 'sensors': None, 'barometric_altitude': 6096.0, 'transponder_code': '2727', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LARGE: 4>}
# {'icao24': 'a4d86a', 'callsign': 'LXJ411  ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -80.0724, 'latitude': 41.9445, 'geo_altitude': 1447.8, 'on_ground': False, 'velocity': 146.42, 'true_track': 257.62, 'vertical_rate': -5.85, 'sensors': None, 'barometric_altitude': 1539.24, 'transponder_code': '7460', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.SMALL: 3>}
# {'icao24': 'aae312', 'callsign': 'N800NJ  ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -107.7685, 'latitude': 36.172, 'geo_altitude': 12694.92, 'on_ground': False, 'velocity': 199.21, 'true_track': 232.45, 'vertical_rate': 0.33, 'sensors': None, 'barometric_altitude': 12192.0, 'transponder_code': '0522', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'ad4f0b', 'callsign': 'DAL1363 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -85.4297, 'latitude': 35.1766, 'geo_altitude': 7543.8, 'on_ground': False, 'velocity': 197.89, 'true_track': 314.79, 'vertical_rate': 0.33, 'sensors': None, 'barometric_altitude': 7307.58, 'transponder_code': '7154', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a3687e', 'callsign': 'AJT886  ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -97.3206, 'latitude': 38.9656, 'geo_altitude': 11894.82, 'on_ground': False, 'velocity': 214.33, 'true_track': 259.77, 'vertical_rate': -0.33, 'sensors': None, 'barometric_altitude': 11582.4, 'transponder_code': '1117', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'a678ef', 'callsign': 'NKS1858 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -85.7217, 'latitude': 40.456, 'geo_altitude': 10081.26, 'on_ground': False, 'velocity': 238.39, 'true_track': 39.22, 'vertical_rate': -4.55, 'sensors': None, 'barometric_altitude': 9944.1, 'transponder_code': '2201', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': '0d0c07', 'callsign': 'VTM787  ', 'origin_country': 'Mexico', 'time_position': 1697328161, 'last_contact': 1697328161, 'longitude': -90.4477, 'latitude': 35.7496, 'geo_altitude': 9494.52, 'on_ground': False, 'velocity': 184.09, 'true_track': 221.26, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 9144.0, 'transponder_code': '4116', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'ac96ad', 'callsign': 'N910AB  ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -84.445, 'latitude': 38.1604, 'geo_altitude': 8641.08, 'on_ground': False, 'velocity': 124.93, 'true_track': 333.33, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 8534.4, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a4c54a', 'callsign': 'N4060G  ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -115.1608, 'latitude': 36.2136, 'geo_altitude': 861.06, 'on_ground': False, 'velocity': 47.1, 'true_track': 319.87, 'vertical_rate': 0.33, 'sensors': None, 'barometric_altitude': 853.44, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a71209', 'callsign': 'N555AL  ', 'origin_country': 'United States', 'time_position': 1697327959, 'last_contact': 1697327960, 'longitude': -115.2036, 'latitude': 36.211, 'geo_altitude': None, 'on_ground': True, 'velocity': 0.19, 'true_track': 11.25, 'vertical_rate': None, 'sensors': None, 'barometric_altitude': None, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LIGHT: 2>}
# {'icao24': 'ad3c16', 'callsign': 'AAL1408 ', 'origin_country': 'United States', 'time_position': 1697328161, 'last_contact': 1697328161, 'longitude': -82.7715, 'latitude': 37.4875, 'geo_altitude': 10469.88, 'on_ground': False, 'velocity': 283.41, 'true_track': 135.96, 'vertical_rate': -4.88, 'sensors': None, 'barometric_altitude': 10256.52, 'transponder_code': '7414', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'ad19f2', 'callsign': 'SKW5481 ', 'origin_country': 'United States', 'time_position': 1697328159, 'last_contact': 1697328159, 'longitude': -87.9202, 'latitude': 41.9674, 'geo_altitude': None, 'on_ground': True, 'velocity': 15.95, 'true_track': 270.0, 'vertical_rate': None, 'sensors': None, 'barometric_altitude': None, 'transponder_code': '0555', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a5954e', 'callsign': 'UAL1257 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328163, 'longitude': -120.2764, 'latitude': 46.4754, 'geo_altitude': 10614.66, 'on_ground': False, 'velocity': 205.45, 'true_track': 309.31, 'vertical_rate': -0.33, 'sensors': None, 'barometric_altitude': 10355.58, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': '0d0c14', 'callsign': 'XARUV   ', 'origin_country': 'Mexico', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -80.776, 'latitude': 32.4483, 'geo_altitude': 11826.24, 'on_ground': False, 'velocity': 239.76, 'true_track': 25.69, 'vertical_rate': -0.33, 'sensors': None, 'barometric_altitude': 11277.6, 'transponder_code': '6072', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a70b23', 'callsign': 'LXJ553  ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328163, 'longitude': -93.1526, 'latitude': 33.3693, 'geo_altitude': 12466.32, 'on_ground': False, 'velocity': 276.16, 'true_track': 31.44, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 11887.2, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.SMALL: 3>}
# {'icao24': 'a1befc', 'callsign': 'UAL1493 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -95.1012, 'latitude': 42.5083, 'geo_altitude': 11148.06, 'on_ground': False, 'velocity': 221.41, 'true_track': 257.38, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 10972.8, 'transponder_code': '7434', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'aa69db', 'callsign': 'ENY3870 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328163, 'longitude': -97.1432, 'latitude': 33.0085, 'geo_altitude': 2788.92, 'on_ground': False, 'velocity': 125.48, 'true_track': 265.06, 'vertical_rate': 18.53, 'sensors': None, 'barometric_altitude': 2674.62, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'aa56b6', 'callsign': 'UAL483  ', 'origin_country': 'United States', 'time_position': 1697328163, 'last_contact': 1697328163, 'longitude': -104.2463, 'latitude': 39.7991, 'geo_altitude': 3703.32, 'on_ground': False, 'velocity': 209.46, 'true_track': 98.19, 'vertical_rate': 10.73, 'sensors': None, 'barometric_altitude': 3573.78, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LARGE: 4>}
# {'icao24': 'aa56b8', 'callsign': 'UAL2328 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -76.6887, 'latitude': 38.7053, 'geo_altitude': 11452.86, 'on_ground': False, 'velocity': 267.21, 'true_track': 37.33, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 11277.6, 'transponder_code': '1056', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LARGE: 4>}
# {'icao24': 'a46e40', 'callsign': 'DAL2404 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -96.1281, 'latitude': 45.6134, 'geo_altitude': 10911.84, 'on_ground': False, 'velocity': 228.91, 'true_track': 287.66, 'vertical_rate': 4.23, 'sensors': None, 'barometric_altitude': 10744.2, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'ad5623', 'callsign': 'AAL2182 ', 'origin_country': 'United States', 'time_position': 1697328163, 'last_contact': 1697328163, 'longitude': -97.6154, 'latitude': 35.877, 'geo_altitude': 10767.06, 'on_ground': False, 'velocity': 181.46, 'true_track': 257.22, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 10363.2, 'transponder_code': '2467', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'ad5628', 'callsign': 'DAL2086 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -91.7573, 'latitude': 39.9873, 'geo_altitude': 9669.78, 'on_ground': False, 'velocity': 255.09, 'true_track': 133.45, 'vertical_rate': 0.33, 'sensors': None, 'barometric_altitude': 9448.8, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a1c5e0', 'callsign': 'ENY3869 ', 'origin_country': 'United States', 'time_position': 1697328163, 'last_contact': 1697328163, 'longitude': -101.2827, 'latitude': 32.0511, 'geo_altitude': 5852.16, 'on_ground': False, 'velocity': 220.01, 'true_track': 81.53, 'vertical_rate': 5.85, 'sensors': None, 'barometric_altitude': 5570.22, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LARGE: 4>}
# {'icao24': 'acdfab', 'callsign': 'DAL607  ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328163, 'longitude': -84.401, 'latitude': 31.9419, 'geo_altitude': 7033.26, 'on_ground': False, 'velocity': 202.71, 'true_track': 179.13, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 6705.6, 'transponder_code': '0237', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'aa9f30', 'callsign': 'N7838W  ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -93.8835, 'latitude': 45.5528, 'geo_altitude': 571.5, 'on_ground': False, 'velocity': 65.01, 'true_track': 256.73, 'vertical_rate': -0.65, 'sensors': None, 'barometric_altitude': 518.16, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a2ded8', 'callsign': 'SWA3029 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -87.526, 'latitude': 38.3897, 'geo_altitude': 8907.78, 'on_ground': False, 'velocity': 249.26, 'true_track': 35.59, 'vertical_rate': -5.2, 'sensors': None, 'barometric_altitude': 8724.9, 'transponder_code': '2355', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'ac2f5a', 'callsign': 'SWA2794 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -78.5317, 'latitude': 38.8277, 'geo_altitude': 10408.92, 'on_ground': False, 'velocity': 196.54, 'true_track': 258.22, 'vertical_rate': 3.25, 'sensors': None, 'barometric_altitude': 10302.24, 'transponder_code': '0526', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'ab033c', 'callsign': 'N8089V  ', 'origin_country': 'United States', 'time_position': 1697328149, 'last_contact': 1697328149, 'longitude': -116.0327, 'latitude': 43.6682, 'geo_altitude': 2324.1, 'on_ground': False, 'velocity': 53.68, 'true_track': 282.17, 'vertical_rate': -0.33, 'sensors': None, 'barometric_altitude': 2225.04, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LIGHT: 2>}
# {'icao24': 'ad694c', 'callsign': 'SWA2602 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328163, 'longitude': -104.3933, 'latitude': 31.2208, 'geo_altitude': 10660.38, 'on_ground': False, 'velocity': 268.79, 'true_track': 102.04, 'vertical_rate': 9.1, 'sensors': None, 'barometric_altitude': 10096.5, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': '4952ab', 'callsign': 'TAP209K ', 'origin_country': 'Portugal', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -72.7892, 'latitude': 40.9333, 'geo_altitude': 3703.32, 'on_ground': False, 'velocity': 145.87, 'true_track': 240.18, 'vertical_rate': -6.18, 'sensors': None, 'barometric_altitude': 3771.9, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a2355d', 'callsign': 'SKW3795 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -94.7424, 'latitude': 42.7418, 'geo_altitude': 10523.22, 'on_ground': False, 'velocity': 235.83, 'true_track': 196.74, 'vertical_rate': -0.33, 'sensors': None, 'barometric_altitude': 10363.2, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LARGE: 4>}
# {'icao24': 'a72533', 'callsign': 'N56GM   ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328163, 'longitude': -84.4327, 'latitude': 35.6646, 'geo_altitude': 3832.86, 'on_ground': False, 'velocity': 99.31, 'true_track': 264.05, 'vertical_rate': 5.2, 'sensors': None, 'barometric_altitude': 3817.62, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'ac498c', 'callsign': 'FDX5393 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -80.4567, 'latitude': 40.9534, 'geo_altitude': 11018.52, 'on_ground': False, 'velocity': 232.2, 'true_track': 226.8, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 10972.8, 'transponder_code': '2504', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a2228b', 'callsign': 'ASA1088 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -121.7262, 'latitude': 45.7431, 'geo_altitude': 9974.58, 'on_ground': False, 'velocity': 225.65, 'true_track': 167.36, 'vertical_rate': 5.2, 'sensors': None, 'barometric_altitude': 9715.5, 'transponder_code': '6656', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LARGE: 4>}
# {'icao24': 'aa9f1c', 'callsign': 'SWA1781 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -83.453, 'latitude': 37.9297, 'geo_altitude': 10881.36, 'on_ground': False, 'velocity': 282.01, 'true_track': 128.33, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 10668.0, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'abacd2', 'callsign': 'UAL1259 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -84.9279, 'latitude': 33.7456, 'geo_altitude': 4358.64, 'on_ground': False, 'velocity': 177.82, 'true_track': 287.86, 'vertical_rate': 9.75, 'sensors': None, 'barometric_altitude': 4274.82, 'transponder_code': '3117', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': '4b1855', 'callsign': 'PJS1839 ', 'origin_country': 'Switzerland', 'time_position': 1697328163, 'last_contact': 1697328163, 'longitude': -117.0337, 'latitude': 32.6125, 'geo_altitude': 4823.46, 'on_ground': False, 'velocity': 197.13, 'true_track': 96.14, 'vertical_rate': 4.88, 'sensors': None, 'barometric_altitude': 4587.24, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LARGE: 4>}
# {'icao24': 'aaef89', 'callsign': 'AAL915  ', 'origin_country': 'United States', 'time_position': 1697328121, 'last_contact': 1697328121, 'longitude': -79.8998, 'latitude': 24.6615, 'geo_altitude': 8023.86, 'on_ground': False, 'velocity': 220.49, 'true_track': 143.16, 'vertical_rate': 3.25, 'sensors': None, 'barometric_altitude': 7528.56, 'transponder_code': '3644', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'ae13a4', 'callsign': 'SLASH45 ', 'origin_country': 'United States', 'time_position': 1697328126, 'last_contact': 1697328162, 'longitude': -95.3922, 'latitude': 33.7934, 'geo_altitude': 7993.38, 'on_ground': False, 'velocity': 173.41, 'true_track': 131.87, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 7612.38, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a950de', 'callsign': 'N7LH    ', 'origin_country': 'United States', 'time_position': 1697328040, 'last_contact': 1697328040, 'longitude': -117.6241, 'latitude': 33.9759, 'geo_altitude': 198.12, 'on_ground': False, 'velocity': 43.73, 'true_track': 270.0, 'vertical_rate': -1.95, 'sensors': None, 'barometric_altitude': 205.74, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LIGHT: 2>}
# {'icao24': 'a90375', 'callsign': 'N680CM  ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -95.5195, 'latitude': 32.6716, 'geo_altitude': 2362.2, 'on_ground': False, 'velocity': 160.63, 'true_track': 164.58, 'vertical_rate': -9.1, 'sensors': None, 'barometric_altitude': 2301.24, 'transponder_code': '1113', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.SMALL: 3>}
# {'icao24': 'abb3be', 'callsign': 'DAL106  ', 'origin_country': 'United States', 'time_position': 1697328163, 'last_contact': 1697328163, 'longitude': -69.5884, 'latitude': 41.5334, 'geo_altitude': 10347.96, 'on_ground': False, 'velocity': 299.75, 'true_track': 70.13, 'vertical_rate': 2.28, 'sensors': None, 'barometric_altitude': 10294.62, 'transponder_code': '1155', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.HEAVY: 6>}
# {'icao24': 'a58e1e', 'callsign': 'SWA3118 ', 'origin_country': 'United States', 'time_position': 1697328161, 'last_contact': 1697328162, 'longitude': -119.638, 'latitude': 36.0775, 'geo_altitude': 9304.02, 'on_ground': False, 'velocity': 226.0, 'true_track': 168.84, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 8839.2, 'transponder_code': '3775', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a963f7', 'callsign': 'FFT2417 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -112.0202, 'latitude': 33.4399, 'geo_altitude': None, 'on_ground': True, 'velocity': 6.17, 'true_track': 140.62, 'vertical_rate': None, 'sensors': None, 'barometric_altitude': None, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'ad5679', 'callsign': 'DAL2711 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -85.4274, 'latitude': 31.3219, 'geo_altitude': 7429.5, 'on_ground': False, 'velocity': 228.74, 'true_track': 4.9, 'vertical_rate': 9.1, 'sensors': None, 'barometric_altitude': 7078.98, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': '47b217', 'callsign': 'NBT01F  ', 'origin_country': 'Norway', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -115.9086, 'latitude': 34.8652, 'geo_altitude': 11620.5, 'on_ground': False, 'velocity': 258.73, 'true_track': 226.53, 'vertical_rate': -6.83, 'sensors': None, 'barometric_altitude': 11079.48, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a3a538', 'callsign': 'FFT1589 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -83.809, 'latitude': 34.1121, 'geo_altitude': 3825.24, 'on_ground': False, 'velocity': 157.03, 'true_track': 230.05, 'vertical_rate': -3.58, 'sensors': None, 'barometric_altitude': 3771.9, 'transponder_code': '2101', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a8f681', 'callsign': 'N677J   ', 'origin_country': 'United States', 'time_position': 1697328161, 'last_contact': 1697328162, 'longitude': -98.1782, 'latitude': 33.0483, 'geo_altitude': 4541.52, 'on_ground': False, 'velocity': 101.11, 'true_track': 282.34, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 4351.02, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LIGHT: 2>}
# {'icao24': 'ae13c5', 'callsign': 'HOOK81  ', 'origin_country': 'United States', 'time_position': 1697328125, 'last_contact': 1697328139, 'longitude': -104.2874, 'latitude': 38.1943, 'geo_altitude': 2164.08, 'on_ground': False, 'velocity': 116.43, 'true_track': 168.79, 'vertical_rate': 1.95, 'sensors': None, 'barometric_altitude': 2049.78, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'ace6e2', 'callsign': 'AAL1158 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -77.925, 'latitude': 38.4368, 'geo_altitude': 7947.66, 'on_ground': False, 'velocity': 180.8, 'true_track': 235.32, 'vertical_rate': 4.88, 'sensors': None, 'barometric_altitude': 7901.94, 'transponder_code': '2002', 'special_purpose_indicator': True, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'a3556f', 'callsign': 'JBU250  ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -72.8213, 'latitude': 41.2473, 'geo_altitude': 7018.02, 'on_ground': False, 'velocity': 237.2, 'true_track': 63.32, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 7010.4, 'transponder_code': '0762', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'ac1042', 'callsign': 'SWA1801 ', 'origin_country': 'United States', 'time_position': 1697328091, 'last_contact': 1697328156, 'longitude': -104.6773, 'latitude': 39.8635, 'geo_altitude': None, 'on_ground': True, 'velocity': 0.0, 'true_track': 180.0, 'vertical_rate': None, 'sensors': None, 'barometric_altitude': None, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a46e6a', 'callsign': 'FFT2329 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328163, 'longitude': -76.2936, 'latitude': 36.7263, 'geo_altitude': 11917.68, 'on_ground': False, 'velocity': 225.15, 'true_track': 198.1, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 11582.4, 'transponder_code': '3304', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'abf025', 'callsign': 'SWA2361 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -82.559, 'latitude': 27.6981, 'geo_altitude': 10706.1, 'on_ground': False, 'velocity': 253.56, 'true_track': 154.27, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 10058.4, 'transponder_code': '1743', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'a2d2d1', 'callsign': 'EJM281  ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328163, 'longitude': -104.9243, 'latitude': 42.4879, 'geo_altitude': 13418.82, 'on_ground': False, 'velocity': 248.39, 'true_track': 322.49, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 13106.4, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a88072', 'callsign': 'NKS1555 ', 'origin_country': 'United States', 'time_position': 1697328161, 'last_contact': 1697328162, 'longitude': -81.3436, 'latitude': 26.7288, 'geo_altitude': 5204.46, 'on_ground': False, 'velocity': 214.43, 'true_track': 308.77, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 4907.28, 'transponder_code': '4534', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'a94b51', 'callsign': 'UAL2720 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -118.3332, 'latitude': 33.9802, 'geo_altitude': 4503.42, 'on_ground': False, 'velocity': 190.98, 'true_track': 44.89, 'vertical_rate': 4.23, 'sensors': None, 'barometric_altitude': 4297.68, 'transponder_code': '4701', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'c01b6c', 'callsign': 'JZA725  ', 'origin_country': 'Canada', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -73.9352, 'latitude': 44.9709, 'geo_altitude': 6233.16, 'on_ground': False, 'velocity': 194.9, 'true_track': 210.63, 'vertical_rate': 11.05, 'sensors': None, 'barometric_altitude': 6339.84, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'adda1e', 'callsign': 'AAL1250 ', 'origin_country': 'United States', 'time_position': 1697327853, 'last_contact': 1697327853, 'longitude': -80.2704, 'latitude': 25.783, 'geo_altitude': 83.82, 'on_ground': False, 'velocity': 78.1, 'true_track': 299.6, 'vertical_rate': -3.58, 'sensors': None, 'barometric_altitude': 99.06, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'a94b50', 'callsign': 'UAL2652 ', 'origin_country': 'United States', 'time_position': 1697328163, 'last_contact': 1697328163, 'longitude': -74.803, 'latitude': 40.8277, 'geo_altitude': 2087.88, 'on_ground': False, 'velocity': 153.54, 'true_track': 50.71, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 2209.8, 'transponder_code': '3521', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LARGE: 4>}
# {'icao24': 'c02e9b', 'callsign': 'JZA913  ', 'origin_country': 'Canada', 'time_position': 1697328162, 'last_contact': 1697328163, 'longitude': -87.6082, 'latitude': 42.2691, 'geo_altitude': 3025.14, 'on_ground': False, 'velocity': 169.29, 'true_track': 218.09, 'vertical_rate': 0.33, 'sensors': None, 'barometric_altitude': 3032.76, 'transponder_code': '2203', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'abad94', 'callsign': 'SWA3870 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -75.3176, 'latitude': 39.8524, 'geo_altitude': 198.12, 'on_ground': False, 'velocity': 64.26, 'true_track': 75.63, 'vertical_rate': -3.58, 'sensors': None, 'barometric_altitude': 312.42, 'transponder_code': '7031', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'a7bbe9', 'callsign': 'JBU247  ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -78.5483, 'latitude': 44.226, 'geo_altitude': 9715.5, 'on_ground': False, 'velocity': 214.7, 'true_track': 281.47, 'vertical_rate': -0.33, 'sensors': None, 'barometric_altitude': 9753.6, 'transponder_code': '3434', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'adda24', 'callsign': 'AAL469  ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -99.5738, 'latitude': 44.4928, 'geo_altitude': 9326.88, 'on_ground': False, 'velocity': 235.29, 'true_track': 291.69, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 9144.0, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'a127d3', 'callsign': 'CXK168  ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -111.173, 'latitude': 32.7223, 'geo_altitude': 3177.54, 'on_ground': False, 'velocity': 56.67, 'true_track': 285.8, 'vertical_rate': -1.95, 'sensors': None, 'barometric_altitude': 3032.76, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a96577', 'callsign': 'DAL504  ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -102.53, 'latitude': 40.812, 'geo_altitude': 11216.64, 'on_ground': False, 'velocity': 218.03, 'true_track': 249.13, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 10972.8, 'transponder_code': '6550', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.HIGH_VORTEX_LARGE: 5>}
# {'icao24': 'ae144f', 'callsign': 'RCH423  ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -119.6083, 'latitude': 36.714, 'geo_altitude': 8016.24, 'on_ground': False, 'velocity': 249.7, 'true_track': 148.31, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 7620.0, 'transponder_code': '3326', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': '4b187d', 'callsign': 'SWR23A  ', 'origin_country': 'Switzerland', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -72.7264, 'latitude': 40.0723, 'geo_altitude': 7962.9, 'on_ground': False, 'velocity': 213.07, 'true_track': 120.47, 'vertical_rate': 5.85, 'sensors': None, 'barometric_altitude': 7901.94, 'transponder_code': '1134', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': '4b187e', 'callsign': 'SWR52   ', 'origin_country': 'Switzerland', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -71.0299, 'latitude': 42.3134, 'geo_altitude': 251.46, 'on_ground': False, 'velocity': 68.7, 'true_track': 20.61, 'vertical_rate': -3.25, 'sensors': None, 'barometric_altitude': 342.9, 'transponder_code': '0740', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'ac21f5', 'callsign': 'N881EE  ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -117.1322, 'latitude': 33.6108, 'geo_altitude': 2849.88, 'on_ground': False, 'velocity': 76.83, 'true_track': 200.38, 'vertical_rate': -4.88, 'sensors': None, 'barometric_altitude': 2781.3, 'transponder_code': '1200', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'accd69', 'callsign': 'DAL1355 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -82.3564, 'latitude': 30.3587, 'geo_altitude': 11612.88, 'on_ground': False, 'velocity': 217.81, 'true_track': 186.1, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 10972.8, 'transponder_code': '7152', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a902ae', 'callsign': 'RAX200  ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -85.6796, 'latitude': 39.7373, 'geo_altitude': 10850.88, 'on_ground': False, 'velocity': 273.35, 'true_track': 70.54, 'vertical_rate': -1.3, 'sensors': None, 'barometric_altitude': 10668.0, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': '4b1886', 'callsign': 'SWR18N  ', 'origin_country': 'Switzerland', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -74.2157, 'latitude': 40.6123, 'geo_altitude': 434.34, 'on_ground': False, 'velocity': 81.22, 'true_track': 25.92, 'vertical_rate': -4.88, 'sensors': None, 'barometric_altitude': 541.02, 'transponder_code': '2507', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': '0d0af2', 'callsign': 'VTM288  ', 'origin_country': 'Mexico', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -98.2429, 'latitude': 28.1975, 'geo_altitude': 7543.8, 'on_ground': False, 'velocity': 244.26, 'true_track': 60.2, 'vertical_rate': 7.8, 'sensors': None, 'barometric_altitude': 7124.7, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': '861f44', 'callsign': 'JAL67   ', 'origin_country': 'Japan', 'time_position': 1697328095, 'last_contact': 1697328096, 'longitude': -156.275, 'latitude': 59.1407, 'geo_altitude': 9311.64, 'on_ground': False, 'velocity': 247.08, 'true_track': 278.5, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 9753.6, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'a83e86', 'callsign': 'JBU1464 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -117.7072, 'latitude': 33.3565, 'geo_altitude': 3421.38, 'on_ground': False, 'velocity': 165.12, 'true_track': 302.4, 'vertical_rate': -4.23, 'sensors': None, 'barometric_altitude': 3246.12, 'transponder_code': '2107', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LARGE: 4>}
# {'icao24': 'a8e2d6', 'callsign': 'DAL2044 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -82.5067, 'latitude': 31.8876, 'geo_altitude': 11247.12, 'on_ground': False, 'velocity': 223.86, 'true_track': 333.08, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 10668.0, 'transponder_code': '1152', 'special_purpose_indicator': True, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.HIGH_VORTEX_LARGE: 5>}
# {'icao24': 'ad9136', 'callsign': 'N9730V  ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -122.3099, 'latitude': 47.1237, 'geo_altitude': 434.34, 'on_ground': False, 'velocity': 38.92, 'true_track': 187.59, 'vertical_rate': 0.98, 'sensors': None, 'barometric_altitude': 426.72, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a9653d', 'callsign': 'AAL1357 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -83.2261, 'latitude': 33.9829, 'geo_altitude': 11795.76, 'on_ground': False, 'velocity': 273.91, 'true_track': 57.89, 'vertical_rate': 0.33, 'sensors': None, 'barometric_altitude': 11285.22, 'transponder_code': '7332', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'acd481', 'callsign': 'AAL434P ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -89.7465, 'latitude': 32.3906, 'geo_altitude': 12512.04, 'on_ground': False, 'velocity': 283.17, 'true_track': 74.73, 'vertical_rate': 0.33, 'sensors': None, 'barometric_altitude': 11887.2, 'transponder_code': '4043', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'aded77', 'callsign': 'JBU974  ', 'origin_country': 'United States', 'time_position': 1697327917, 'last_contact': 1697327970, 'longitude': -70.9417, 'latitude': 24.3132, 'geo_altitude': 11033.76, 'on_ground': False, 'velocity': 228.78, 'true_track': 354.97, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 10347.96, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'ad41cd', 'callsign': 'SWA745  ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328163, 'longitude': -118.0989, 'latitude': 33.542, 'geo_altitude': 9502.14, 'on_ground': False, 'velocity': 233.92, 'true_track': 336.82, 'vertical_rate': 9.1, 'sensors': None, 'barometric_altitude': 9022.08, 'transponder_code': '1365', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'a7126a', 'callsign': 'N555EH  ', 'origin_country': 'United States', 'time_position': 1697328150, 'last_contact': 1697328162, 'longitude': -112.0153, 'latitude': 37.218, 'geo_altitude': 10218.42, 'on_ground': False, 'velocity': 206.02, 'true_track': 256.87, 'vertical_rate': 0.33, 'sensors': None, 'barometric_altitude': 9761.22, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# ...
# {'icao24': 'aa0ec7', 'callsign': 'RPA3477 ', 'origin_country': 'United States', 'time_position': 1697327959, 'last_contact': 1697327959, 'longitude': -74.1735, 'latitude': 40.6974, 'geo_altitude': None, 'on_ground': True, 'velocity': 2.83, 'true_track': 219.38, 'vertical_rate': None, 'sensors': None, 'barometric_altitude': None, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LARGE: 4>}
# {'icao24': 'aaa0e9', 'callsign': 'N784RR  ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -93.5083, 'latitude': 34.5107, 'geo_altitude': 10507.98, 'on_ground': False, 'velocity': 175.02, 'true_track': 126.63, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 10058.4, 'transponder_code': '4064', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a7de0b', 'callsign': 'FDX311  ', 'origin_country': 'United States', 'time_position': 1697328056, 'last_contact': 1697328125, 'longitude': -113.941, 'latitude': 38.4955, 'geo_altitude': 11468.1, 'on_ground': False, 'velocity': 229.56, 'true_track': 265.76, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 10972.8, 'transponder_code': '1112', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.HEAVY: 6>}
# {'icao24': 'aa7833', 'callsign': 'DAL1025 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328163, 'longitude': -95.2622, 'latitude': 38.7202, 'geo_altitude': 11262.36, 'on_ground': False, 'velocity': 204.34, 'true_track': 300.57, 'vertical_rate': -0.33, 'sensors': None, 'barometric_altitude': 10972.8, 'transponder_code': '6670', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LARGE: 4>}
# {'icao24': 'abc0e4', 'callsign': 'SWA2896 ', 'origin_country': 'United States', 'time_position': 1697328154, 'last_contact': 1697328162, 'longitude': -77.0385, 'latitude': 38.842, 'geo_altitude': None, 'on_ground': True, 'velocity': 0.0, 'true_track': 126.56, 'vertical_rate': None, 'sensors': None, 'barometric_altitude': None, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'a12403', 'callsign': 'UAL2128 ', 'origin_country': 'United States', 'time_position': 1697328163, 'last_contact': 1697328163, 'longitude': -90.4549, 'latitude': 30.0989, 'geo_altitude': 2423.16, 'on_ground': False, 'velocity': 134.58, 'true_track': 309.1, 'vertical_rate': 12.03, 'sensors': None, 'barometric_altitude': 2362.2, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a05dba', 'callsign': 'UAL584  ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -109.3496, 'latitude': 38.0768, 'geo_altitude': 11422.38, 'on_ground': False, 'velocity': 222.16, 'true_track': 239.22, 'vertical_rate': -0.33, 'sensors': None, 'barometric_altitude': 10972.8, 'transponder_code': '0067', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'a78e2a', 'callsign': 'N586WD  ', 'origin_country': 'United States', 'time_position': 1697328069, 'last_contact': 1697328069, 'longitude': -101.9101, 'latitude': 40.9346, 'geo_altitude': 8473.44, 'on_ground': False, 'velocity': 152.27, 'true_track': 81.84, 'vertical_rate': -0.33, 'sensors': None, 'barometric_altitude': 8229.6, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LIGHT: 2>}
# {'icao24': 'a05dbc', 'callsign': 'UAL2089 ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -113.091, 'latitude': 35.5245, 'geo_altitude': 10881.36, 'on_ground': False, 'velocity': 239.28, 'true_track': 236.75, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 10363.2, 'transponder_code': '7314', 'special_purpose_indicator': True, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'a09a01', 'callsign': 'N138ME  ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -122.4337, 'latitude': 37.8479, 'geo_altitude': 731.52, 'on_ground': False, 'velocity': 50.53, 'true_track': 125.47, 'vertical_rate': -0.33, 'sensors': None, 'barometric_altitude': 716.28, 'transponder_code': '0244', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'c00734', 'callsign': 'WJA1591 ', 'origin_country': 'Canada', 'time_position': 1697328162, 'last_contact': 1697328163, 'longitude': -95.3091, 'latitude': 42.776, 'geo_altitude': 11148.06, 'on_ground': False, 'velocity': 216.71, 'true_track': 309.51, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 10972.8, 'transponder_code': '6034', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'c067ae', 'callsign': 'ACA752  ', 'origin_country': 'Canada', 'time_position': 1697328162, 'last_contact': 1697328162, 'longitude': -71.3206, 'latitude': 43.8757, 'geo_altitude': 9387.84, 'on_ground': False, 'velocity': 261.82, 'true_track': 131.02, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 9448.8, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a60bbd', 'callsign': 'DPJ489  ', 'origin_country': 'United States', 'time_position': 1697328162, 'last_contact': 1697328163, 'longitude': -77.5925, 'latitude': 38.8484, 'geo_altitude': 1866.9, 'on_ground': False, 'velocity': 129.07, 'true_track': 188.71, 'vertical_rate': 13.33, 'sensors': None, 'barometric_altitude': 1965.96, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# c:\Users\tobyt\Desktop\Coding\Personal\delayedflighttracker\publish_flights_example.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/tobyt/Desktop/Coding/Personal/delayedflighttracker/publish_flights_example.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> await poll_flights()
#
# File c:\Users\tobyt\Desktop\Coding\Personal\delayedflighttracker\env\Lib\site-packages\pyensign\ensign.py:721, in authenticate.<locals>.wrap_coroutine.<locals>.wrapper(*args, **kwargs)
#     719     async with Ensign(*auth_args, **auth_kwargs) as client:
#     720         _client = client
# --> 721         res = await coro(*args, **kwargs)
#     722 except Exception as e:
#     723     _client = None
#
# c:\Users\tobyt\Desktop\Coding\Personal\delayedflighttracker\publish_flights_example.ipynb Cell 7 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/tobyt/Desktop/Coding/Personal/delayedflighttracker/publish_flights_example.ipynb#W6sZmlsZQ%3D%3D?line=29'>30</a> @authenticate(cred_path=ENSIGN_CREDS_PATH)
#      <a href='vscode-notebook-cell:/c%3A/Users/tobyt/Desktop/Coding/Personal/delayedflighttracker/publish_flights_example.ipynb#W6sZmlsZQ%3D%3D?line=30'>31</a> async def poll_flights():
#      <a href='vscode-notebook-cell:/c%3A/Users/tobyt/Desktop/Coding/Personal/delayedflighttracker/publish_flights_example.ipynb#W6sZmlsZQ%3D%3D?line=31'>32</a>     for i in range(10):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/tobyt/Desktop/Coding/Personal/delayedflighttracker/publish_flights_example.ipynb#W6sZmlsZQ%3D%3D?line=32'>33</a>         async for data in get_flights():
#      <a href='vscode-notebook-cell:/c%3A/Users/tobyt/Desktop/Coding/Personal/delayedflighttracker/publish_flights_example.ipynb#W6sZmlsZQ%3D%3D?line=33'>34</a>             print(data)
#      <a href='vscode-notebook-cell:/c%3A/Users/tobyt/Desktop/Coding/Personal/delayedflighttracker/publish_flights_example.ipynb#W6sZmlsZQ%3D%3D?line=34'>35</a>         await asyncio.sleep(INTERVAL_SEC)
#
# File c:\Users\tobyt\Desktop\Coding\Personal\delayedflighttracker\env\Lib\site-packages\pyensign\ensign.py:842, in publisher.<locals>.wrap_async_generator.<locals>.wrapper(*args, **kwargs)
#     837     raise RuntimeError(
#     838         "publish requires a connection to Ensign, please use the authenticate decorator to provide your credentials"
#     839     )
#     841 # Yield the values from the generator
# --> 842 async for val in coro(*args, **kwargs):
#     843     if val is None:
#     844         yield val
#
# c:\Users\tobyt\Desktop\Coding\Personal\delayedflighttracker\publish_flights_example.ipynb Cell 7 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/tobyt/Desktop/Coding/Personal/delayedflighttracker/publish_flights_example.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> async with ClientSession() as session:
#       <a href='vscode-notebook-cell:/c%3A/Users/tobyt/Desktop/Coding/Personal/delayedflighttracker/publish_flights_example.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a>     async with OpenSky(session=session) as opensky:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/tobyt/Desktop/Coding/Personal/delayedflighttracker/publish_flights_example.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a>         await opensky.authenticate(OPENSKY_CREDS)
#       <a href='vscode-notebook-cell:/c%3A/Users/tobyt/Desktop/Coding/Personal/delayedflighttracker/publish_flights_example.ipynb#W6sZmlsZQ%3D%3D?line=6'>7</a>         response = await opensky.get_states(bounding_box=BOUNDING_BOX)
#       <a href='vscode-notebook-cell:/c%3A/Users/tobyt/Desktop/Coding/Personal/delayedflighttracker/publish_flights_example.ipynb#W6sZmlsZQ%3D%3D?line=7'>8</a>         for vector in response.states:
#
# File c:\Users\tobyt\Desktop\Coding\Personal\delayedflighttracker\env\Lib\site-packages\python_opensky\opensky.py:49, in OpenSky.authenticate(self, auth, contributing_user)
#      47 self._auth = auth
#      48 try:
# ---> 49     await self.get_states()
#      50 except OpenSkyUnauthenticatedError as exc:
#      51     self._auth = None
#
# File c:\Users\tobyt\Desktop\Coding\Personal\delayedflighttracker\env\Lib\site-packages\python_opensky\opensky.py:166, in OpenSky.get_states(self, bounding_box)
#     163     params[MAX_LONGITUDE] = bounding_box.max_longitude
#     164     credit_cost = self.calculate_credit_costs(bounding_box)
# --> 166 data = await self._request("states/all", data=params)
#     168 if data["states"] is None:
#     169     data["states"] = []
#
# File c:\Users\tobyt\Desktop\Coding\Personal\delayedflighttracker\env\Lib\site-packages\python_opensky\opensky.py:115, in OpenSky._request(self, uri, data)
#     113 try:
#     114     async with async_timeout.timeout(self.request_timeout):
# --> 115         response = await self.session.request(
#     116             METH_GET,
#     117             url.with_query(data),
#     118             auth=self._auth,
#     119             headers=headers,
#     120         )
#     121         response.raise_for_status()
#     122 except asyncio.TimeoutError as exception:
#
# File c:\Users\tobyt\Desktop\Coding\Personal\delayedflighttracker\env\Lib\site-packages\aiohttp\client.py:562, in ClientSession._request(self, method, str_or_url, params, data, json, cookies, headers, skip_auto_headers, auth, allow_redirects, max_redirects, compress, chunked, expect100, raise_for_status, read_until_eof, proxy, proxy_auth, timeout, verify_ssl, fingerprint, ssl_context, ssl, proxy_headers, trace_request_ctx, read_bufsize)
#     560     async with ceil_timeout(real_timeout.connect):
#     561         assert self._connector is not None
# --> 562         conn = await self._connector.connect(
#     563             req, traces=traces, timeout=real_timeout
#     564         )
#     565 except asyncio.TimeoutError as exc:
#     566     raise ServerTimeoutError(
#     567         "Connection timeout " "to host {}".format(url)
#     568     ) from exc
#
# File c:\Users\tobyt\Desktop\Coding\Personal\delayedflighttracker\env\Lib\site-packages\aiohttp\connector.py:540, in BaseConnector.connect(self, req, traces, timeout)
#     537         await trace.send_connection_create_start()
#     539 try:
# --> 540     proto = await self._create_connection(req, traces, timeout)
#     541     if self._closed:
#     542         proto.close()
#
# File c:\Users\tobyt\Desktop\Coding\Personal\delayedflighttracker\env\Lib\site-packages\aiohttp\connector.py:901, in TCPConnector._create_connection(self, req, traces, timeout)
#     899     _, proto = await self._create_proxy_connection(req, traces, timeout)
#     900 else:
# --> 901     _, proto = await self._create_direct_connection(req, traces, timeout)
#     903 return proto
#
# File c:\Users\tobyt\Desktop\Coding\Personal\delayedflighttracker\env\Lib\site-packages\aiohttp\connector.py:1178, in TCPConnector._create_direct_connection(self, req, traces, timeout, client_error)
#    1175 port = hinfo["port"]
#    1177 try:
# -> 1178     transp, proto = await self._wrap_create_connection(
#    1179         self._factory,
#    1180         host,
#    1181         port,
#    1182         timeout=timeout,
#    1183         ssl=sslcontext,
#    1184         family=hinfo["family"],
#    1185         proto=hinfo["proto"],
#    1186         flags=hinfo["flags"],
#    1187         server_hostname=hinfo["hostname"] if sslcontext else None,
#    1188         local_addr=self._local_addr,
#    1189         req=req,
#    1190         client_error=client_error,
#    1191     )
#    1192 except ClientConnectorError as exc:
#    1193     last_exc = exc
#
# File c:\Users\tobyt\Desktop\Coding\Personal\delayedflighttracker\env\Lib\site-packages\aiohttp\connector.py:980, in TCPConnector._wrap_create_connection(self, req, timeout, client_error, *args, **kwargs)
#     978 try:
#     979     async with ceil_timeout(timeout.sock_connect):
# --> 980         return await self._loop.create_connection(*args, **kwargs)  # type: ignore[return-value]  # noqa
#     981 except cert_errors as exc:
#     982     raise ClientConnectorCertificateError(req.connection_key, exc) from exc
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\asyncio\base_events.py:1069, in BaseEventLoop.create_connection(self, protocol_factory, host, port, ssl, family, proto, flags, sock, local_addr, server_hostname, ssl_handshake_timeout, ssl_shutdown_timeout, happy_eyeballs_delay, interleave)
#    1067 for addrinfo in infos:
#    1068     try:
# -> 1069         sock = await self._connect_sock(
#    1070             exceptions, addrinfo, laddr_infos)
#    1071         break
#    1072     except OSError:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\asyncio\base_events.py:973, in BaseEventLoop._connect_sock(self, exceptions, addr_info, local_addr_infos)
#     971             else:
#     972                 raise OSError(f"no matching local address with {family=} found")
# --> 973     await self.sock_connect(sock, address)
#     974     return sock
#     975 except OSError as exc:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\asyncio\selector_events.py:634, in BaseSelectorEventLoop.sock_connect(self, sock, address)
#     632 self._sock_connect(fut, sock, address)
#     633 try:
# --> 634     return await fut
#     635 finally:
#     636     # Needed to break cycles when an exception occurs.
#     637     fut = None
#
# CancelledError:
